# %%
library(Polychrome)
library(RColorBrewer)
library(ggplot2)

# %%
# Rcolor brewer
colors <- RColorBrewer::brewer.pal(n = 9, name = 'Set1')
colors
swatch(colors)
# Out:
# [1] "#E41A1C" "#377EB8" "#4DAF4A" "#984EA3" "#FF7F00" "#FFFF33" "#A65628"
# [8] "#F781BF" "#999999"
# Plot with title “colors”

# %%
RColorBrewer::display.brewer.all(colorblindFriendly = TRUE)
# Out:
# plot without title

# %%
color1 <- kelly.colors(22)
color1
swatch(color1)
# Out:
#          white          black         yellow         purple         orange
#      "#f2f3f4"      "#222222"      "#f3c300"      "#875692"      "#f38400"
#      lightblue            red           buff           gray          green
#      "#a1caf1"      "#be0032"      "#c2b280"      "#848482"      "#008856"
#   purplishpink           blue  yellowishpink         violet   orangeyellow
#      "#e68fac"      "#0067a5"      "#f99379"      "#604e97"      "#f6a600"
#    purplishred greenishyellow   reddishbrown    yellowgreen yellowishbrown
#      "#b3446c"      "#dcd300"      "#882d17"      "#8db600"      "#654522"
#  reddishorange     olivegreen
#      "#e25822"      "#2b3d26"
# Plot with title “color1”

# %%
colors2 <- alphabet.colors(26)
colors2
swatch(colors2)
# Out:
#    amethyst        blue     caramel      damson       ebony      forest
#   "#AA0DFE"   "#3283FE"   "#85660D"   "#782AB6"   "#565656"   "#1C8356"
#       green       honey        iron        jade    kingcrab    lavender
#   "#16FF32"   "#F7E1A0"   "#E2E2E2"   "#1CBE4F"   "#C4451C"   "#DEA0FD"
#     magenta        navy      orange        pink    quagmire         red
#   "#FE00FA"   "#325A9B"   "#FEAF16"   "#F8A19F"   "#90AD1C"   "#F6222E"
#         sea   turquoise ultraviolet      violet        wine     xanthin
#   "#1CFFCE"   "#2ED9FF"   "#B10DA1"   "#C075A6"   "#FC1CBF"   "#B00068"
#      yellow      zinnia
#   "#FBE426"   "#FA0087"
# Plot with title “colors2”

# %%
# paletter
library(paletteer)
#https://r-graph-gallery.com/color-palette-finder

# %%
# has to install different libraries

# %%
library(viridis)
# Out:
# Loading required package: viridisLite

# %%
swatch(viridis(10))
# Out:
# Plot with title “viridis(10)”

# %%
swatch(plasma(10))  # magma., inferno
# Out:
# Plot with title “plasma(10)”

# %%
barplot(1:10, col = inferno(10), horiz = TRUE)
# Out:
# plot without title

# %%
barplot(1:10)
# Out:
# plot without title
